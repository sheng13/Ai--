# %% [markdown]
# <a href="https://colab.research.google.com/github/sheng13/Ai--/blob/main/%E3%80%8C0709_Colab_LINE_Bot_with_GEMINI_Rag_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 5.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://alla-mammillate-tawanna.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://alla-mammillate-tawanna.ngrok-free.dev
# True

# %%
from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch

# === 初始化 Google Gemini ===
client = genai.Client(api_key=gemini_api_key)

google_search_tool = Tool(
   google_search=GoogleSearch()
)

chat = client.chats.create(
    model="gemini-2.5-flash",
    config=GenerateContentConfig(
        system_instruction="你是一個中文的AI助手，請用繁體中文回答",
        tools=[google_search_tool],
        response_modalities=["TEXT"],
    )
)

# %%
def stateful_query(payload):
    response = chat.send_message(message=payload)
    return response.text

# %%
result = stateful_query("iphone歷史")
print(result)
# Out:
# 蘋果公司的iPhone，又稱蘋果手機，是一款顛覆性的智慧型手機系列，自2007年首次亮相以來，便搭載其自主研發的iOS行動作業系統，對全球手機市場及人們的日常生活產生了深遠的影響。
#
# **iPhone的誕生與早期發展 (2007-2010)**
#
# *   **2007年1月9日：初代iPhone發表**
#     由當時的蘋果公司執行長史提夫·賈伯斯在Macworld Expo舊金山展會上發布，並於同年6月29日正式發售。 這款手機以其3.5吋多點觸控螢幕、基於OS X的iPhone OS（後更名為iOS）、以及能完整開啟電腦版網頁的Safari瀏覽器等革命性特性，重新定義了手機，開啟了觸控式手機時代。 《時代雜誌》將其評為「2007年的年度發明」。
#
# *   **2008年：iPhone 3G與App Store**
#     iPhone 3G的推出為蘋果生態系統帶來了重大轉折，即應用商店App Store的問世。 這使得第三方應用程式得以在iPhone上運行，極大地擴展了手機的功能性。 iPhone 3G也首次支援3G網路和GPS功能。
#
# *   **2009年：iPhone 3GS**
#     在硬體和速度上進行了升級，為後續的iPhone發展奠定了基礎。
#
# *   **2010年：iPhone 4**
#     帶來了Retina顯示器，大幅提升了螢幕解析度，並引入了FaceTime視訊通話功能。
#
# **iPhone的進化與創新 (2011-2017)**
#
# *   **2011年：iPhone 4S與Siri**
#     iPhone 4S搭載了A5處理器，並首次引入了Siri語音助理，這是一款內建於iOS系統中的人工智能助理軟體，可透過自然語言處理技術與手機互動。
#
# *   **2012年：iPhone 5**
#     螢幕尺寸從3.5吋增至4吋，並改用Lightning連接埠。
#
# *   **2013年：iPhone 5S與Touch ID**
#     iPhone 5S首次搭載了64位元的A7處理器，並引入了Touch ID指紋辨識技術，提升了手機的安全性與便利性。 同年也推出了色彩繽紛的iPhone 5C。
#
# *   **2014年：iPhone 6與iPhone 6 Plus**
#     蘋果首次推出兩種螢幕尺寸，分別為4.7吋和5.5吋，迎合了市場對大螢幕手機的需求。
#
# *   **2015年：iPhone 6S與3D Touch**
#     iPhone 6S和6S Plus維持了前代的外觀設計，但加入了Taptic Engine與3D Touch功能，可感應螢幕按壓的力度。
#
# *   **2016年：iPhone SE (第一代) 與iPhone 7**
#     iPhone SE以iPhone 5S的外觀搭配iPhone 6S的硬體規格，提供更實惠的選擇。 iPhone 7和7 Plus則取消了3.5mm耳機孔，並引入了雙鏡頭系統（Plus機型）。
#
# *   **2017年：iPhone 8、8 Plus與iPhone X**
#     為紀念iPhone問世十週年，蘋果推出了iPhone X，首次採用了OLED全螢幕設計，取消了Home鍵，並引入了Face ID臉部辨識技術，成為iPhone設計上的一大里程碑。 iPhone 8和8 Plus則延續了傳統設計，並支援無線充電。
#
# **全面屏時代與多元化發展 (2018至今)**
#
# *   **2018年：iPhone XR、XS與XS Max**
#     蘋果推出了三款新機，iPhone XR作為更具性價比的選擇，採用LCD螢幕。 iPhone XS和XS Max則進一步提升了OLED螢幕的顯示效果和A12仿生處理器的性能。
#
# *   **2019年：iPhone 11、11 Pro與11 Pro Max**
#     iPhone 11系列首次搭載了三鏡頭系統（Pro機型），大幅提升了攝影能力。
#
# *   **2020年：iPhone SE (第二代) 與iPhone 12系列**
#     第二代iPhone SE以iPhone 8的外觀搭載A13仿生處理器。 iPhone 12系列則全面改用OLED螢幕，並支援5G網路，同時恢復了方正的邊框設計。
#
# *   **2021年：iPhone 13系列**
#     iPhone 13系列在Pro機型上首次採用120Hz ProMotion高更新率螢幕，並在相機、續航等方面有所提升。
#
# *   **2022年：iPhone SE (第三代) 與iPhone 14系列**
#     第三代iPhone SE搭載A15仿生處理器。 iPhone 14 Pro和Pro Max引入了「動態島」設計，取代了原有的瀏海造型，並搭載最新的A16仿生處理器。
#
# *   **2023年：iPhone 15系列**
#     iPhone 15全系列採用動態島設計，並全面改用USB-C接口，Pro系列更首次採用航空級鈦金屬外框設計。
#
# *   **2024年：iPhone 16系列 (預測)**
#     預計將新增相機鍵、強化AI攝影功能、搭載A18晶片並提升續航力。
#
# *   **2025年：iPhone 17系列與iPhone Air (預測)**
#     預計將在處理器、網路晶片、充電效率和外觀設計上有所創新，並可能推出超薄款iPhone Air。
#
# 截至2020年，iPhone的銷量已超過22億台，其成功使蘋果公司成為全球最有價值的上市公司之一。 iPhone持續的創新不僅改變了手機本身，也深刻影響了通訊、社交、娛樂、工作和消費模式。

# %%
result2 = stateful_query("iphone創始人")
print(result2)
# Out:
# tool_code
# print(google_search.search(queries=['iphone founder', 'who founded apple', 'Steve Jobs iPhone presentation']))
# thought
# The user is asking about the founder of the iPhone. I should provide information about the key individual(s) involved in the creation and launch of the iPhone. Since the iPhone is an Apple product, it's also relevant to mention the founders of Apple Inc. and specifically the person who unveiled the iPhone.蘋果公司的聯合創辦人**史提夫·賈伯斯（Steve Jobs）**被廣泛認為是iPhone的創始人，因為他主導了iPhone的開發，並於2007年1月9日在Macworld Expo上向全世界發表了這款革命性的智慧型手機。
#
# 史提夫·賈伯斯不僅是蘋果公司的核心人物，也是一位具有遠見的創新者，他的領導力與對產品細節的執著塑造了iPhone的誕生與發展。 他在發布會上展示的iPhone，以其多點觸控螢幕、創新的介面以及將手機、iPod和網際網路通訊設備三者合一的理念，徹底改變了手機產業。

# %%
from flask import Flask, request, abort
import logging
import os
import time
from google.genai import types

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    MessagingApiBlob,
    ReplyMessageRequest,
    TextMessage
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
    FileMessageContent
)

app = Flask(__name__)

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
app.logger.setLevel(logging.INFO)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)

# 儲存檔案的目錄
UPLOAD_DIR = "/content/uploaded_files"
os.makedirs(UPLOAD_DIR, exist_ok=True)

# 儲存每個使用者的對話 session 和上傳的檔案
user_sessions = {}  # {user_id: {"chat": chat_object, "uploaded_file": gemini_file}}

def get_user_session(user_id):
    """取得或建立使用者的對話 session"""
    if user_id not in user_sessions:
        # 建立新的對話 session
        new_chat = client.chats.create(
            model="gemini-2.5-flash",
            config=GenerateContentConfig(
                system_instruction="你是一個中文的AI助手，請用繁體中文回答。如果使用者有提供參考文件，請根據文件內容回答問題。",
                tools=[google_search_tool],
                response_modalities=["TEXT"],
            )
        )
        user_sessions[user_id] = {
            "chat": new_chat,
            "uploaded_file": None
        }
    return user_sessions[user_id]

def download_line_file(message_id, file_name):
    """從 LINE 下載使用者上傳的檔案"""
    with ApiClient(configuration) as api_client:
        line_bot_blob_api = MessagingApiBlob(api_client)
        file_content = line_bot_blob_api.get_message_content(message_id)

        file_path = os.path.join(UPLOAD_DIR, file_name)

        with open(file_path, 'wb') as f:
            f.write(file_content)

        return file_path

def upload_file_to_gemini(file_path):
    """上傳檔案到 Gemini Files API"""
    uploaded_file = client.files.upload(
        file=file_path,
        config={'display_name': os.path.basename(file_path)}
    )

    # 等待檔案處理完成
    while uploaded_file.state.name == "PROCESSING":
        print("檔案處理中...")
        time.sleep(1)
        uploaded_file = client.files.get(name=uploaded_file.name)

    if uploaded_file.state.name == "FAILED":
        raise Exception("檔案上傳處理失敗")

    return uploaded_file

def query_with_rag(user_id, question):
    """使用 RAG 模式回答問題"""
    session = get_user_session(user_id)
    uploaded_file = session["uploaded_file"]

    if uploaded_file:
        # 有上傳檔案，使用 RAG 模式
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=[
                types.Content(
                    role="user",
                    parts=[
                        types.Part.from_uri(
                            file_uri=uploaded_file.uri,
                            mime_type=uploaded_file.mime_type
                        ),
                        types.Part.from_text(text=f"請根據上述提供的檔案內容，用繁體中文回答這個問題：{question}")
                    ]
                )
            ]
        )
        return response.text
    else:
        # 沒有上傳檔案，使用一般多輪對話
        response = session["chat"].send_message(message=question)
        return response.text

@app.route("/", methods=['POST'])
def callback():
    signature = request.headers['X-Line-Signature']
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature.")
        abort(400)

    return 'OK'

@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    """處理文字訊息"""
    text = event.message.text
    user_id = event.source.user_id

    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        if text.startswith('AI '):
            prompt = text[3:]
            try:
                # 使用 RAG 或一般對話
                reply_text = query_with_rag(user_id, prompt)

                # 檢查是否有上傳檔案，加上提示
                session = get_user_session(user_id)
                if session["uploaded_file"]:
                    reply_text = f"📄 [RAG 模式]\n\n{reply_text}"

                line_bot_api.reply_message_with_http_info(
                    ReplyMessageRequest(
                        reply_token=event.reply_token,
                        messages=[TextMessage(text=reply_text)]
                    )
                )
            except Exception as e:
                line_bot_api.reply_message_with_http_info(
                    ReplyMessageRequest(
                        reply_token=event.reply_token,
                        messages=[TextMessage(text=f"❌ 發生錯誤：{str(e)}")]
                    )
                )
        elif text == "清除文件":
            # 清除使用者上傳的檔案
            session = get_user_session(user_id)
            session["uploaded_file"] = None
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="✅ 已清除上傳的文件，恢復一般對話模式。")]
                )
            )
        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="請輸入「AI 問題」來開始對話\n或上傳 TXT/PDF 檔案啟用 RAG 模式")]
                )
            )

@handler.add(MessageEvent, message=FileMessageContent)
def handle_file_message(event):
    """處理使用者上傳的檔案"""
    user_id = event.source.user_id
    file_name = event.message.file_name

    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        # 檢查檔案類型
        if not (file_name.endswith('.txt') or file_name.endswith('.pdf')):
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="⚠️ 目前只支援 TXT 或 PDF 檔案")]
                )
            )
            return

        try:
            # 下載檔案
            file_path = download_line_file(event.message.id, file_name)
            print(f"檔案已下載：{file_path}")

            # 上傳到 Gemini
            uploaded_file = upload_file_to_gemini(file_path)
            print(f"檔案已上傳到 Gemini：{uploaded_file.uri}")

            # 儲存到使用者 session
            session = get_user_session(user_id)
            session["uploaded_file"] = uploaded_file

            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=f"✅ 檔案「{file_name}」上傳成功！\n\n現在您可以輸入「AI 問題」來詢問關於這份文件的問題。\n\n輸入「清除文件」可恢復一般對話模式。")]
                )
            )
        except Exception as e:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=f"❌ 檔案處理失敗：{str(e)}")]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# INFO:__main__:Request body: {"destination":"U287a3d06a20703e880b3c1fda99f4939","events":[]}
# INFO:__main__:Invalid signature.
# INFO:werkzeug:127.0.0.1 - - [07/Jan/2026 23:09:53] "POST / HTTP/1.1" 400 -
# BODY:  {"destination":"U287a3d06a20703e880b3c1fda99f4939","events":[]}
